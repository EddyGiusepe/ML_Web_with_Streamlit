# %% [markdown]
# <h1 align="center">pré-processamento de data</h1>

# %% [markdown]
# Data Scientist.: Dr.Eddy Giusepe Chirinos Isidro

# %%
# Importando as nossas bibliotecas
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
inpi_db = pd.read_excel("inpi_db.xlsx")
inpi_db.head()
# Out:
#         Ano Siglas  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# 0      Acre     AC     2     6     1     2     2     4    12    34    21
# 1   Alagoas     AL    51    41    41    18    22    32    62   270   134
# 2  Amazonas     AM    86    67    91    51    51    76   135   649   245
# 3     Amapá     AP     1     0     3     2     1     0     4    22     7
# 4     Bahia     BA   254   243   204   174   132   209   477  1937   729
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017
# 0    14    16    12    11     7    24    12    24    13
# 1   126   137    94    91    67   127   192   173   263
# 2   362   369   297   238   143   379   441   390   522
# 3     4    17     5     8     6    17    11    23    33
# 4  1019  1009   841   821   572  1337  1467  1456  1928

# %%
df = pd.read_excel("data.xlsx", decimal='.')
df.head()
# Out:
#     Ano  Acre  Alagoas  Amazonas  Amapá  Bahia  Ceará  Distrito Federal  \
# 0  2000     2       51        86      1    254    264               183
# 1  2001     6       41        67      0    243    260               158
# 2  2002     1       41        91      3    204    323               108
# 3  2003     2       18        51      2    174    135                97
# 4  2004     2       22        51      1    132    185               108
#
#    Espírito Santo  Goiás  ...  Rio de Janeiro  Rio Grande do Norte  Rondônia  \
# 0             157    201  ...            1375                   79        12
# 1             149    179  ...            1668                   95        18
# 2             129    295  ...            1266                   63        12
# 3              62     89  ...             854                   23         4
# 4             128    135  ...            1016                   45         6
#
# ...

# %%
df.shape
# Out:
# (18, 29)

# %%
df[['Acre', 'Alagoas', 'Espírito Santo']].plot()
# Out:
# <AxesSubplot: >
